# %% [markdown]
# 🚀 MINI PROJECT #2 — STUDENT RECORD MANAGER (CLI)

# %% [markdown]
# 🧩 Problem Statement
#
# Build a simple command-line Student Record Manager using Python.
#
# 🎯 FEATURES
#
# Add student
#
# View all students
#
# Search by roll number
#
# Delete student
#
# Exit program
#
# 🪜 STEP-BY-STEP LOGIC
#
# 1️⃣ Use a list of dictionaries
# 2️⃣ Each student = {roll, name, marks}
# 3️⃣ Use while loop menu
# 4️⃣ Perform operations based on user choice

# %%
student=[]
while True:
    print("\n 1.Add 2.View 3.Search 4.Delete 5.Exit")
    choice=input("enter your choice:")

    if choice=="1":
        rollno=input("Roll:")
        name=input("name:")
        marks=input("Marks:")
        student.append({"rollNO":rollno,"Name":name,"Mark":marks})
        print(student)
        print("STUDENTS ARE ADDED!!!")
    elif choice=="2":
        for s in student:
            print(s)
    elif choice=="3":
        r=input("enter a rollno to search:")
        for s in student:
            if s[rollno]==r:
                print(s)
    elif choice=="4":
        r=input("enter a rollno to delete:")
        for s in student:
            if s[rollno]!=r:
                print(s)
                print(student)
        print("ROll NO IS DELETED")
    elif choice=="5":
        break
# Out:
#  1.Add 2.View 3.Search 4.Delete 5.Exit
# [{'rollNO': '123', 'Name': 'murugakarthika', 'Mark': '89'}]
# STUDENTS ARE ADDED!!!
#
#  1.Add 2.View 3.Search 4.Delete 5.Exit
#
#  1.Add 2.View 3.Search 4.Delete 5.Exit
#
#  1.Add 2.View 3.Search 4.Delete 5.Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 while True:
#       3     print("\n 1.Add 2.View 3.Search 4.Delete 5.Exit")
# ----> 4     choice=input("enter your choice:")
#       6     if choice=="1":
#       7         rollno=input("Roll:")
#
# File c:\Users\mohan\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Users\mohan\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
